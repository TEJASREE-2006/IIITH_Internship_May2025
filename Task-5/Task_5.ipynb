# %% [markdown]
# <a href="https://colab.research.google.com/github/TEJASREE-2006/IIITH_Internship_May2025/blob/main/Task-5/Task_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !find / -name "skin_lesions_dataset.zip"

# %%
# !mv /skin_lesions_dataset.zip /content/

# %%
# !unzip -q /content/skin_lesions_dataset.zip -d /content/

# %%
# !git clone https://github.com/ultralytics/ultralytics
# %cd ultralytics
# !pip install -e .

# %%
# %cd /content/ultralytics

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # You can use 'yolov8s.pt' or 'yolov8m.pt' for more accuracy
model.train(data='/content/skin_lesions_dataset/lesions.yaml', epochs=50, imgsz=640, batch=8)

# %%
import os

# Check all YOLO training folders
runs_dir = '/content/ultralytics/runs/detect'
print("Training runs found:")
print(os.listdir(runs_dir))

# %%
# !find /content/ultralytics/runs/detect/ -name "results.png"

# %%
from IPython.display import Image, display
display(Image(filename='/content/ultralytics/runs/detect/train3/results.png'))

# %%
# !find /content/ultralytics/runs/detect/ -name "best.pt"

# %%
from ultralytics import YOLO

# Replace with actual path from find command
model = YOLO('/content/ultralytics/runs/detect/train3/weights/best.pt')

# %%
from google.colab import files
uploaded = files.upload()

# %%
import os
os.listdir()

# %%
results = model('img16.jpeg')  # Replace with actual filename
results[0].show()
